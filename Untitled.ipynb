# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns  # Added import for sns which was missing

""" Load dataset"""
csv = pd.read_csv("C:/Users/Raghav Sharma/Downloads/1) iris.csv")
"""basic info"""
print(csv.head())
print(csv.tail())
print(csv.describe())
print(csv.info())
print("\n Missing value in each column ")
print(csv.isnull().sum())
print("\n No of duplicated rows ", csv.duplicated().sum())

# 3. Data distribution (Histograms)
plt.figure(figsize=(10,8))  # Set figure size separately
# Create histograms for each numerical column
numerical_columns = csv.select_dtypes(include=['float64', 'int64']).columns
for i, column in enumerate(numerical_columns):
    plt.subplot(2, 2, i+1)  # Create a 2x2 grid of subplots
    plt.hist(csv[column], bins=20, edgecolor="black")
    plt.title(f'Histogram of {column}')
plt.tight_layout()  # Adjust layout
plt.suptitle("Histograms of Iris Features")
plt.show()

# 4. Boxplots (to see outliers)
plt.figure(figsize=(10,6))
sns.boxplot(data=csv.drop(columns=["species"]))  # excluding categorical column
plt.title("Boxplots of Numerical Features")
plt.show()

# 5. Correlation Heatmap
plt.figure(figsize=(8,6))
sns.heatmap(csv.drop(columns=["species"]).corr(), annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# ...
